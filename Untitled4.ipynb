# %% [markdown]
# <a href="https://colab.research.google.com/github/jsz162/lth/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
인공지능 사관학교 프리코스 과제 목차

  1주차 과제

  
    1) 음성인식
 
       음성인식이란 사람이 음성으로 낸 명령을 컴퓨터가 듣고 대신 수행해내는 
       기술 이고 과거에는 소리를 문자로 바꾸는 정도에 사용할수 있는 분야가
       한정되어 있었지만 하드웨어의 엄청난 발전으로 인해 지금에 이르러서는 
       게임,통역,교육,보안 과같은 여러 분야에서도 사용하고있고 여기서 더욱 더 발전한다면
       아직 생각지도 못한 분야에서 활용할 방법이 있는 가능성이 높은 기술이라고 생각합니다.

       시중에서 찾아볼수있는 음성인식
          삼성전자의 '빅스비'
          KT '기가 지니'
          SK텔레콤  '누구'


      2)자율주행

        자동차,청소기,철도,항공기,선박 과 같이 사람이 운전 해야 하거나 따로 설정을 하여 움직일수 있게
        해주어야하는 기계를 사람의 조작과 설정 없이 기계에 탑재된 인공지능 스스로 판단하여 움직이는 기술입니다. 
        자율 주행은 극복 하기 어려운 요소들이 하나씩 있습니다.
        예로 하면 도로에는 동물과 인간의 갑작스러운 도로 침입, 바다에서 일어나는 자연재해 같은 요소를
        해결 하는것이 자율주행의 관건인것 같습니다.

        시중에서 찾아볼수 있는 자율주행
           로봇청소기
           기차(국내 자율주행 기차 : 용인 경전철,의정부 경전철,인천 2호선)


        3)인공지능 이미지

          인간,동물,사물 과같은 것들을 기계가 본것을 분류,판별 하여 사람의 조작 없이 
          기계가 본것 스스로 정의를 내리게 하는 기술이며 다양한 산업에서 각광 받고 있는 기술입니다.
          이 기술의 어려움 중 하나로 노이즈를 판별해 내는 것이 어렵다는 것이고
          그다음 하나로는 이미지의 색깔,구도,모양이 유사하여 분석에 혼란을 주는 경우 입니다.
          이러한 기술들만 잘 극복 할수 있다면 의료,보안,생산시설,판매 등 여러 분야에서
          활용할수있는 산업에 특화된 기술이라고 생각합니다.

          시중에서 찾아볼수 있는 인공지능 이미지
             무인 스토어
             보안 검색대


        4)인공지능 언어

          국가간 다양한 언어들을 번역해 주는 기술입니다
          매우 간단하게 정의 할수 있지만 위의 3가지 기술중 가장 실현 가능성이 높고
          다른 기술의 발전과 함께 같이 성장할수 있는 기술이라고 생각합니다.
          음성인식과 언어번역 그리고 이미지 기술 이 3가지 기술이 합쳐지고 발전 한다면
          기계가 듣고 본 여러 나라의 언어를 해석하여 인간에게 전달해 주는것도 가능할것이고
          그게 가능해지면 생산공장,교육,여행,게임 과 같은 여러 분야에 활용할수 있으며
          완벽히 발전 한다면 언어의 장벽 이라는 단어는 세상에서 사라질 단어가 될것이라 생각 합니다.

          시중에서 찾아볼수 있는 인공지능 언어 (번역)
             플리토   (통합 번역 플랫폼)
             파파고   (네이버 AI번역기 )
             S번역기  (삼성전자 번역 애플리케이션)



             위의 4가지 기술의 자료를 조사하면서 느낀점은 4가지 기술 모두 컴퓨터와 세탁기 자동차와 같이
             인간의 삶에 편리를 제공한다는 점인것 같습니다.
